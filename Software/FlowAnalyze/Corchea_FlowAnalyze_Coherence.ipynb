# %%
from PIL import Image
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import itertools

# %%
#import image
im = Image.open("test channel coherence (green).jpg")
l,w = im.size
pix_count = list(im.getdata())
pix_array = np.array(im)
work_array = pix_array[:,:,1]
#count the 1s in the binary array in axis of choice
ones = np.count_nonzero(work_array)
#start the analysis
py,px = work_array.shape
size = 45 #mm channel length
ch_width = 5 #mm channel width
pix_val= size/px #mm
pix_area = pix_val**2 #mm2
x = ones*(size/px)

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=394x51 at 0x1A25FC5D10>

# %%
plt.imshow(work_array) # I should find a way to segment in a continuous way

# %%
plt.plot((1-(work_array>0)).sum(axis=0))

# %%
channel_estarea = size*ch_width
channel_estarea
# Out:
# 225

# %%
channel_finarea = pix_area*((l*w)-ones)
channel_finarea
# Out:
# 179.32486665464194

# %%
coherence_perc = channel_finarea*100/channel_estarea
coherence_perc
# Out:
# 79.69994073539642

# %% [markdown]
# #### Fin

# %%
im = Image.open("test channel 2.jpg (green).jpg")
l,w = im.size
pix_count = list(im.getdata())
pix_array = np.array(im)
work_array = pix_array[:,:,1]
#count the 1s in the binary array in axis of choice
ones = np.count_nonzero(work_array)
#start the analysis
py,px = work_array.shape
size = 45 #mm channel length
ch_width = 5 #mm channel width
pix_val= size/px #mm
pix_area = pix_val**2 #mm2
x = ones*(size/px)
channel_estarea = size*ch_width
channel_finarea = pix_area*((l*w)-ones)
coherence_perc = channel_finarea*100/channel_estarea
coherence_perc
# Out:
# 89.44559228650138

# %%
plt.plot((1-(work_array>0)).sum(axis=0))

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=396x76 at 0x1A26DF04D0>

# %%
pix_area
# Out:
# 0.013044654590430053

# %%
ones
# Out:
# 6347

# %%
channel_finarea = pix_area*((l*w)-ones)

# %%
channel_finarea #mm2
# Out:
# 179.32486665464194

# %%
45*5
# Out:
# 225

# %%
(l*w)-ones #this is to get the complemet of ones in the array
# Out:
# 13747

# %%
coherence_perc = channel_finarea*100/(size*ch_width)

# %%
coherence_perc
# Out:
# 79.69994073539642
